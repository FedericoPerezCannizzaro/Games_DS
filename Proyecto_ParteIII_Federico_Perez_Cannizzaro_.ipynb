# %%
from google.colab import drive
import os
import pandas as pd
import numpy as np
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Steam**
# steam es una plataforma de videojuegos usada en todo el mundo. Actualmente es la plataforma de videojuegos de PC en la que la gente mas confianza tiene en utilizar sus datos mas sensibles como por ejemplo:
#
# *   Tarjeta de credito
# *   Direccion del Hogar

# %% [markdown]
# # Parte 1 investigacion del Dataset

# %%
df= pd.read_csv('/content/gdrive/MyDrive/data/juegos_steam/games.csv',sep=',')
df.head(1)
# Out:
#    AppID              Name  Release date Estimated owners  Peak CCU  \
# 0  20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
#
#                                       About the game Supported languages  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...         ['English']  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
#
#   Median playtime two weeks             Developers             Publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
#
#                                           Categories               Genres  \
# 0  Single-player,Multi-player,Steam Achievements,...  Casual,Indie,Sports
#
#                           Tags  \
# 0  Indie,Casual,Sports,Bowling
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [1 rows x 39 columns]

# %%
#formateo fechas
df['Release date'] = pd.DatetimeIndex(df['Release date'])
df.head(1)
# Out:
#    AppID              Name Release date Estimated owners  Peak CCU  \
# 0  20200  Galactic Bowling   2008-10-21        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
#
#                                       About the game Supported languages  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...         ['English']  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
#
#   Median playtime two weeks             Developers             Publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
#
#                                           Categories               Genres  \
# 0  Single-player,Multi-player,Steam Achievements,...  Casual,Indie,Sports
#
#                           Tags  \
# 0  Indie,Casual,Sports,Bowling
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [1 rows x 39 columns]

# %%
import datetime as dt
df['Year'] = df['Release date'].dt.year
resultado = df.groupby(['Year'])[['Year','Name']].head(4)
total = df['Name'].count()
total
# Out:
# 85097

# %% [markdown]
# # ***Luego de formatear un poco***
#
# 1: A lo largo de los años, desde que esta plataforma se encuentra ¿podriamos considerar que la popularidad de los videojuegos a aumentado a lo largo de los años? para eso tenemos el siguiente grafico
#
# Teniendo en cuenta la cantidad de juegos publicados durante el periodo de su publicacion hasta su actualidad podemos comprobar que el pico de juegos publicados se acerca a 16000 juegos publicados dentro de la plataforma (en este caso en especifico no tomaremos en cuenta el 2024 ya que aun el año no finaliza). Gracias a eso podemos notar que desde la pandemia, la publicacion de videojuegos aumento considerablemente pasando de un valor aproximado de 9000 en 2020 en el comienzo a 12000 a finales de la pandemia

# %%
#agrupo juegos segun su fecha
total_fechas = df.groupby(['Year']).size()
#creo figura
fig, ax = plt.subplots(figsize=(10, 6))
#tomo como index los años + las sumas de sus valores
ax.bar(total_fechas.index, total_fechas.values)
ax.set_title('Total de juegos publicados')
ax.set_ylabel('juegos')
ax.set_xlabel('Año')
# Rotamos las etiquetas del eje x para una mejor visualización
plt.xticks(rotation=45)

# Muestra la gráfica
plt.show()

# %% [markdown]
# # 2- si analizamos los generos dentro de los videojuego publicados ¿podemos encontrar cual es el genero mas popular?
#
# - Analizando el histplot podemos notar que hay un valor atípico

# %%
generos =  df['Genres'].str.split(',', expand=True).stack().value_counts()

fig = plt.figure()
#ax = plt.axes()

ax = sns.histplot(generos, kde=True, stat='density', linewidth=0)

ax.set_title("Distribución generos de videojuegos")
plt.show()

# %% [markdown]
# Si traducimos el histpliot podemos notar que este valor atipico hace referencia al genero **"indie"** lo que muestra que actualmente hay un boom de publicaciones de juegos indies

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Crear el gráfico de barras
generos.plot(kind='bar', ax=ax)

# Configurar el título y etiquetas de los ejes
ax.set_title('Distribución de géneros de juegos')
ax.set_ylabel('Cantidad de juegos')
ax.set_xlabel('Género')
# Out:
# Text(0.5, 0, 'Género')

# %% [markdown]
# # 3: Actividad en la aplicacion
# Analizamos las tendencias respecto a la cantidad de juegos pulicados, generos publicados. podemos decir que la actividad dentro de Steam se ve en aumento.

# %%
steam_scatterplot = df[['Median playtime forever','Average playtime two weeks','Median playtime two weeks']]
#generos_2020_2023_t = steam_2020_2023_t['Genres'].str.split(',', expand=True).stack().value_counts()
#steam_2020_2023_t['num_genres'] = steam_2020_2023_t['Genres'].str.split(',').apply(len)
sizes = steam_scatterplot ['Median playtime forever'] * 1

# %%
scatterplot = steam_scatterplot


# customize the scatter plot


sns.scatterplot(x=steam_scatterplot['Average playtime two weeks'], y=steam_scatterplot['Median playtime two weeks'], hue='Median playtime forever', size=sizes, sizes=(200, 1000), data=steam_scatterplot, palette = 'RdBu')


# add labels and title

plt.xlabel("Promedio jugadores cada dos semanas")

plt.ylabel("Media de jugadores cada dos semanas")

plt.title("Historico de usuarios concurrentes")



# display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. ¿los juegos con estimaciones de propietarios más altas tienden a tener más usuarios concurrentes en promedio?
#
#
# Si comparamos las columnas
#
#
# 1.   Peak CCU : toma los valores maximos de usuarios reccurentes que tubo un juego
# 2.   Estimates Owners: cantidad estimada de usuarios por juego
#
# podremos ver que los juegos que mas propietarios tienen fueron los que mas usuarios concurrentes tuvieron. mostrando valores muy altos mientras mas cantidad de jugadores tenga.

# %%
steam_violin_x = df['Estimated owners'].dropna()
steam_violin_y = df['Peak CCU'].dropna()

# Crear el gráfico de violín
plt.figure(figsize=(10, 6))  # Ajustar el tamaño de la figura
sns.violinplot(x=steam_violin_x, y=steam_violin_y, linewidth=6)  # Aumentar el ancho de la línea del violín


# Ajustar los labels del eje x
plt.xlabel('Estimados de Propietarios', fontsize=12)
plt.xticks(rotation=45)  # Rotar los labels del eje x para que sean legibles

# Añadir título y mostrar el gráfico
plt.title('Distribución: usuario concurrentes / cantidad de usuarios ', fontsize=14)
plt.ylabel('current User', fontsize=12)
plt.show()

# %% [markdown]
# # 5. analizando las valoraciones de los usuarios
# Podemos observar que los usuarios tienden a dar valoraciones positivas en ambas visualizaciones. Sin embargo, en el segundo gráfico, que abarca el período de 2020 a 2024, se aprecia una ausencia de recomendaciones por parte de los usuarios en los últimos años.

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)
ax[0].plot(df['Year'].index, df['Positive'], label='Valoraciones Positivas hist',color = 'green')
ax[1].plot(df['Year'].index, df['Negative'], label='Valoraciones Negativas hist', color='red')
ax[2].plot(df['Year'].index, df['Recommendations'], label='Juegos que fueron recomendados', color='blue')
ax[0].set_title('ratio likes dislikes hist')
ax[2].set_xlabel('valoraciones hist')
ax[1].set_ylabel('year')

ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
Steam_2020_2023 = df[df['Release date'].dt.year.isin([2020, 2021, 2022, 2023,2024])]
steam_2020_2023_t = Steam_2020_2023[['Peak CCU','Price','Median playtime forever']]
steam_val = Steam_2020_2023[['Positive','Negative','Recommendations','Year']].head()

# %%
sizes = steam_2020_2023_t['Median playtime forever'] * 20
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)
ax[0].plot(steam_val['Year'].index, steam_val['Positive'], label='Valoraciones Positivas 2020 / 2024')
ax[1].plot(steam_val['Year'].index, steam_val['Negative'], label='Valoraciones Negativas 2020 / 2024', color='C1')
ax[2].plot(steam_val['Year'].index, steam_val['Recommendations'], label='Juegos que fueron recomendados', color='C2')
ax[0].set_title('ratio likes dislikes 2020 / 2024')
ax[2].set_xlabel('valoraciones')
ax[1].set_ylabel('Year')

ax[0].legend()
ax[1].legend()
ax[2].legend()

# %% [markdown]
# # 6.Distribucion de sistemas operativos
# -En caso de querer priorizar actualizaciones o ciertos descuentos se deberia priorizar los usuarios que posean windows

# %%
os_w = df['Windows'].astype(int).sum()
os_m = df['Mac'].astype(int).sum()
os_l = df['Linux'].astype(int).sum()
cantidad_juegos = len(df)

valores = [os_w,os_m,os_l]
etiquetas = ['Windows','Mac','Linux']
fig, ax = plt.subplots()
plt.pie(valores, labels=etiquetas)
plt.show()

# %% [markdown]
# # Parte 2
#
# Para intentar tener una mejor proyeccion de que juegos deberian ser recomendados a la hora de realizar descuentos. Priorizando los juegos que son mas populares

# %% [markdown]
#  **Dataset Steam**
#
#  Dentro de este dataset, se buscara la distribucion de los datos viendo como valores la distribucion entre los valores de cada videojuego y su media de juego de cada dos semanas. En este caso se buscara mantener valores que superen el 0.

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
import sys
sys.setrecursionlimit(2000)
dataset = df[['Price','Median playtime two weeks']]
dataset = dataset.loc[dataset['Median playtime two weeks'] * dataset['Price'] != 0 ]
sampled_data = dataset.sample(n = 1500, random_state = 42)
X = sampled_data.iloc[:, [0,1]].values
plt.figure(figsize=(5,3))
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

# %%
dataset
# Out:
#        Price  Peak CCU  Median playtime two weeks
# 47     59.99      2164                        311
# 57     59.99      7571                        130
# 66      3.49        49                         79
# 71      2.99       133                         20
# 93     23.99       358                         24
# ...      ...       ...                        ...
# 83776  39.99      6882                        107
# 83843  24.99       306                        128
# 84121   6.29      1307                        114
# 84261  17.99       158                         10
# 84408  13.49      1135                        725
#
# [1770 rows x 3 columns]

# %% [markdown]
# **Aprendizaje no supervisado: Grafico de dispersion**
# en este grafico de dispersion podemos ver segun el tiempo de juego lo siguiente:
# - El cluster rojo representa juegos con poca cantidad de tiempo de juego invertido,tambien se ve una mayor variedad dentro del eje x en cuanto a los valores de las medias de juego
# -El azul representa juegos con un alto tiempo de juego medio
# - El verde presenta la mayor cantidad de tiempo de juego
#
# tambien podemos apreciar que el precio de los juegos menores a 40 dolares son los que presentan mayor cantidad horas jugadas.

# %%
model = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_
plt.scatter(X[labels==0, 0], X[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(X[labels==1, 0], X[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(X[labels==2, 0], X[labels==2, 1], s=50, marker='o', color='green')
plt.show()

# %% [markdown]
# **Aprendizaje Supervizado Arbol de Decisiones**

# %% [markdown]
# Por otro lado, teniendo en cuenta que gradico de dispersion nos muestra la dispersion del precio y la media semanal de horas de juego. Para tener un mejor estadistica, ahora compararemos la media de juego semanal dividiendolas en este caso con los generos de juegos existentes dentro de Steam.

# %%
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %% [markdown]
# Entiendo que la logica detras de lo realizado tiene sentido, sin embargo es imposible entender lo que resulto de esto.

# %%
"""

Cargar los datos de generos y quito las medias de juego que son = 0
dentro de generos utilizo .get_dummies(sep=',') que divide los generos
agregandoles 1 cuando pertenecen al genero y 0 cuando no

"""
generos = df['Genres'].str.get_dummies(sep=',')
df_concat = pd.concat([df['Median playtime two weeks'],generos],axis =1)
df_concat = df_concat.loc[df_concat['Median playtime two weeks'] != 0 ]
#defino x y
X = df_concat.drop(columns=['Median playtime two weeks'])
y = df_concat['Median playtime two weeks']

clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)
# Obtener las etiquetas únicas de y como strings
class_names = y.unique().astype(str)

# Graficar el árbol de decisión
fig = plt.figure(figsize=(18, 10))
_= tree.plot_tree(clf, feature_names=X.columns, class_names=class_names,filled=True)
plt.show()

# %% [markdown]
# intentamos achicar un poco para leerlo mejor

# %%
"""

Cargar los datos de generos y quito las medias de juego que son = 0
dentro de generos utilizo .get_dummies(sep=',') que divide los generos
agregandoles 1 cuando pertenecen al genero y 0 cuando no.
DEL 2024

"""

Steam_2024 = df[df['Release date'].dt.year == 2014]
generos_24 = Steam_2024['Genres'].str.get_dummies(sep=',')
df_concatt = pd.concat([Steam_2024['Median playtime two weeks'],generos_24],axis =1)
df_concatt = df_concatt.loc[df_concatt['Median playtime two weeks'] != 0 ]
df_concatt = df_concatt.dropna()
#defino x y
X = df_concatt.drop(columns=['Median playtime two weeks'])
y = df_concatt['Median playtime two weeks']

clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)
# Obtener las etiquetas únicas de y como strings
class_names = y.unique().astype(str)

# Graficar el árbol de decisión
fig = plt.figure(figsize=(18, 10))
_= tree.plot_tree(clf, feature_names=X.columns, class_names=class_names,filled=True)
plt.show()

# %% [markdown]
# A pesar de eliminar los Nan y los 0 y filtrando por un año me sigue siendo dificil identificar los resultados.

# %% [markdown]
# **Verificamos al Dataset**

# %%
 from sklearn.datasets import load_breast_cancer
 from sklearn.ensemble import RandomForestClassifier
 from sklearn.model_selection import train_test_split
 from sklearn import metrics
 import pandas as pd
 import numpy as np
 from matplotlib import pyplot as plt
 import seaborn as sns
 sns.set_style('whitegrid')

# %%
data = pd.read_csv('/content/gdrive/MyDrive/data/juegos_steam/games.csv',sep=',')
# definimos matriz de diseño X y vector respuesta y
generos = df['Genres'].str.get_dummies(sep=',')
feature_X = ['Price']
y = data['Median playtime two weeks']
X = generos
# Separamos en entrenamiento/test en razon 80/20 %
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)
# Creamos un modelo Random Forest con parametros por defect
modelo = RandomForestClassifier(random_state=1)
modelo.fit(X_train, y_train)
# Obtenemos las predicciones del modelo con X_test
preds = modelo.predict(X_test)

# %%
confusion = metrics.confusion_matrix(y_test, preds)
confusion.ravel()
# Out:
# array([16606,     0,     0, ...,     0,     0,     0])

# %%
# Todas las metricas en uno
print(metrics.classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     16609
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00         3
#            5       0.00      0.00      0.00         4
#            6       0.00      0.00      0.00         5
#            7       0.00      0.00      0.00         3
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00         7
#           11       0.00      0.00      0.00         3
#           12       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         1
#           14       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         3
#           16       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         4
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         4
#           20       0.00      0.00      0.00         1
#           21       0.00      0.00      0.00         2
#           22       0.00      0.00      0.00         3
#           23       0.00      0.00      0.00         5
#           24       0.00      0.00      0.00         5
#           25       0.00      0.00      0.00         1
#           26       0.00      0.00      0.00         1
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00         3
#           31       0.00      0.00      0.00         4
#           32       0.00      0.00      0.00         4
#           33       0.00      0.00      0.00         3
#           35       0.00      0.00      0.00         2
#           36       0.00      0.00      0.00         4
#           37       0.00      0.00      0.00         1
#           39       0.00      0.00      0.00         2
#           40       0.00      0.00      0.00         3
#           43       0.00      0.00      0.00         2
#           45       0.00      0.00      0.00         2
#           46       0.00      0.00      0.00         1
#           47       0.00      0.00      0.00         2
#           48       0.00      0.00      0.00         3
#           49       0.00      0.00      0.00         2
#           50       0.00      0.00      0.00         1
#           52       0.00      0.00      0.00         3
#           53       0.00      0.00      0.00         1
#           54       0.00      0.00      0.00         3
#           56       0.00      0.00      0.00         1
#           59       0.00      0.00      0.00         1
#           60       0.00      0.00      0.00         2
#           61       0.00      0.00      0.00         1
#           62       0.00      0.00      0.00         2
#           63       0.00      0.00      0.00         1
#           64       0.00      0.00      0.00         2
#           65       0.00      0.00      0.00         1
#           67       0.00      0.00      0.00         1
#           68       0.00      0.00      0.00         2
#           69       0.00      0.00      0.00         1
#           70       0.00      0.00      0.00         1
#           71       0.00      0.00      0.00         1
#           73       0.00      0.00      0.00         3
#           75       0.00      0.00      0.00         1
#           76       0.00      0.00      0.00         1
#           79       0.00      0.00      0.00         2
#           81       0.00      0.00      0.00         3
#           82       0.00      0.00      0.00         3
#           83       0.00      0.00      0.00         3
#           85       0.00      0.00      0.00         1
#           87       0.00      0.00      0.00         1
#           88       0.00      0.00      0.00         1
#           89       0.00      0.00      0.00         1
#           90       0.00      0.00      0.00         1
#           91       0.00      0.00      0.00         1
#           93       0.00      0.00      0.00         1
#           94       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           96       0.00      0.00      0.00         1
#           98       0.00      0.00      0.00         2
#           99       0.00      0.00      0.00         1
#          100       0.00      0.00      0.00         1
#          102       0.00      0.00      0.00         1
#          107       0.00      0.00      0.00         2
#          109       0.00      0.00      0.00         1
#          112       0.00      0.00      0.00         1
#          114       0.00      0.00      0.00         2
#          117       0.00      0.00      0.00         2
#          118       0.00      0.00      0.00         3
#          120       0.00      0.00      0.00         1
#          122       0.00      0.00      0.00         1
#          127       0.00      0.00      0.00         1
#          128       0.00      0.00      0.00         1
#          129       0.00      0.00      0.00         1
#          130       0.00      0.00      0.00         1
#          132       0.00      0.00      0.00         1
#          133       0.00      0.00      0.00         1
#          135       0.00      0.00      0.00         1
#          136       0.00      0.00      0.00         1
#          137       0.00      0.00      0.00         1
#          138       0.00      0.00      0.00         1
#          143       0.00      0.00      0.00         2
#          145       0.00      0.00      0.00         1
#          146       0.00      0.00      0.00         2
#          150       0.00      0.00      0.00         1
#          153       0.00      0.00      0.00         1
#          155       0.00      0.00      0.00         1
#          158       0.00      0.00      0.00         1
#          159       0.00      0.00      0.00         2
#          160       0.00      0.00      0.00         3
#          161       0.00      0.00      0.00         1
#          163       0.00      0.00      0.00         2
#          164       0.00      0.00      0.00         1
#          166       0.00      0.00      0.00         2
#          167       0.00      0.00      0.00         1
#          169       0.00      0.00      0.00         2
#          170       0.00      0.00      0.00         1
#          177       0.00      0.00      0.00         1
#          182       0.00      0.00      0.00         1
#          186       0.00      0.00      0.00         1
#          187       0.00      0.00      0.00         1
#          189       0.00      0.00      0.00         1
#          192       0.00      0.00      0.00         1
#          195       0.00      0.00      0.00         2
#          196       0.00      0.00      0.00         1
#          198       0.00      0.00      0.00         3
#          199       0.00      0.00      0.00         2
#          201       0.00      0.00      0.00         2
#          202       0.00      0.00      0.00         1
#          204       0.00      0.00      0.00         1
